# %%
#codigo pacheco 6to tel
import pandas as pd

# %%
pd.read_csv("top_100_anime_movie.csv")
# Out:
#     rank                                              title  rating    votes  \
# 0      1                Ramayana: The Legend of Prince Rama     9.2    7,549
# 1      2                                      Spirited Away     8.6  756,112
# 2      3      Meiji Tokyo Renka Movie: Yumihari no Serenade     8.5       39
# 3      4             Natsu e no tunnel, Sayonara no deguchi     8.5       23
# 4      5                         Attack on Titan: Chronicle     8.5   10,421
# ..   ...                                                ...     ...      ...
# 95    96  Mobile Suit Gundam: The Origin IV - Eve of Des...     7.7      462
# 96    97                            Dou Kyu Sei: Classmates     7.7    2,742
# 97    98         The Shimajiro Movie: Shimajiro in Bookland     7.7       25
# 98    99                                     In This Corner     7.7   11,242
# 99   100                                       Asatte Dansu     7.7       10
#
# ...

# %%
pd.read_csv("top_100_anime_movie.csv", index_col = 0) 
#indexo con la columna del ranking y no con la generada automaticamente
# Out:
#                                                   title  rating    votes  \
# rank
# 1                   Ramayana: The Legend of Prince Rama     9.2    7,549
# 2                                         Spirited Away     8.6  756,112
# 3         Meiji Tokyo Renka Movie: Yumihari no Serenade     8.5       39
# 4                Natsu e no tunnel, Sayonara no deguchi     8.5       23
# 5                            Attack on Titan: Chronicle     8.5   10,421
# ...                                                 ...     ...      ...
# 96    Mobile Suit Gundam: The Origin IV - Eve of Des...     7.7      462
# 97                              Dou Kyu Sei: Classmates     7.7    2,742
# 98           The Shimajiro Movie: Shimajiro in Bookland     7.7       25
# 99                                       In This Corner     7.7   11,242
# 100                                        Asatte Dansu     7.7       10
#
#       year  minutes                         genre    gross
# rank
# ...

# %%
pd.read_csv("top_100_anime_movie.csv", index_col = 0, usecols = ["rank", "title", "rating"]) 
#indexo con la columna del ranking y selecciono para ver solo las columnas del ranking, del titulo y de la puntuacion
# Out:
#                                                   title  rating
# rank
# 1                   Ramayana: The Legend of Prince Rama     9.2
# 2                                         Spirited Away     8.6
# 3         Meiji Tokyo Renka Movie: Yumihari no Serenade     8.5
# 4                Natsu e no tunnel, Sayonara no deguchi     8.5
# 5                            Attack on Titan: Chronicle     8.5
# ...                                                 ...     ...
# 96    Mobile Suit Gundam: The Origin IV - Eve of Des...     7.7
# 97                              Dou Kyu Sei: Classmates     7.7
# 98           The Shimajiro Movie: Shimajiro in Bookland     7.7
# 99                                       In This Corner     7.7
# 100                                        Asatte Dansu     7.7
#
# [100 rows x 2 columns]

# %%
top100 = pd.read_csv("top_100_anime_movie.csv", index_col = 0, usecols = ["rank", "title", "rating"])
#guardo la tabla de arriba en la variable top100
top100
# Out:
#                                                   title  rating
# rank
# 1                   Ramayana: The Legend of Prince Rama     9.2
# 2                                         Spirited Away     8.6
# 3         Meiji Tokyo Renka Movie: Yumihari no Serenade     8.5
# 4                Natsu e no tunnel, Sayonara no deguchi     8.5
# 5                            Attack on Titan: Chronicle     8.5
# ...                                                 ...     ...
# 96    Mobile Suit Gundam: The Origin IV - Eve of Des...     7.7
# 97                              Dou Kyu Sei: Classmates     7.7
# 98           The Shimajiro Movie: Shimajiro in Bookland     7.7
# 99                                       In This Corner     7.7
# 100                                        Asatte Dansu     7.7
#
# [100 rows x 2 columns]

# %%
top100.to_csv("aMovie_rank_title_rating.csv", index = False)
#exporto la tabla top100 (sin el indice generado automaticamente)
#se puede cambiar el formato escribiendo to_excel por ejemplo

# %%
TOP = pd.read_csv("top_100_anime_movie.csv", index_col = 0) 
TOP[["rating"]] #selecciono solo la columna del puntaje
# Out:
#       rating
# rank
# 1        9.2
# 2        8.6
# 3        8.5
# 4        8.5
# 5        8.5
# ...      ...
# 96       7.7
# 97       7.7
# 98       7.7
# 99       7.7
# 100      7.7
#
# [100 rows x 1 columns]

# %%
TOP[["rating"]].mean() #muestro el promedio de los puntajes
# Out:
# rating    8.001
# dtype: float64

# %%
TOP[["year"]] #ahora selecciono solo la columna del año de estreno
# Out:
#       year
# rank
# 1     1993
# 2     2001
# 3     2015
# 4     2022
# 5     2020
# ...    ...
# 96    2016
# 97    2016
# 98    2016
# 99    2016
# 100   1991
#
# [100 rows x 1 columns]

# %%
TOP[["year"]].max() #muestro de que año es la pelicula mas nueva del top
# Out:
# year    2022
# dtype: int64

# %%
TOP[["year"]].min() #muestro de que año es la pelicula mas vieja del top
# Out:
# year    1979
# dtype: int64
